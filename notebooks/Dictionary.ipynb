# %%
ubaekwe = dict(Name = ["Obinna", "Nnamdi", "Ifeanyi", "Queen"],
            Age = [47, 52, 48, 44],
            Height = [1.74, 1.77, 1.74, 1.75],
            Origin = ["Nigerian", "Nigerian", "Nigerian", "Nigerian"]
              )

# %%
#Change key name
ubaekwe["Nationality"] = ubaekwe.pop("Origin")

# %%
# Add "Uba" as a last name to every string in the list using map 
ubaekwe["Name"] = list(map(lambda x: f"{x} Uba", ubaekwe["Name"]))

# %%
ubaekwe
# Out:
# {'Name': ['Obinna Uba', 'Nnamdi Uba', 'Ifeanyi Uba', 'Queen Uba'],
#  'Age': [47, 52, 48, 44],
#  'Height': [1.74, 1.77, 1.74, 1.75],
#  'Nationality': ['Nigerian', 'Nigerian', 'Nigerian', 'Nigerian']}

# %%
# Function to change nationality for a given person
def change_nationality(nationality, name):
    if name == "Obinna Uba":
        return "British"
    return nationality
ubaekwe["Nationality"] = list(map(change_nationality, ubaekwe["Nationality"], ubaekwe["Name"]))

# %%
ubaekwe
# Out:
# {'Name': ['Obinna Uba', 'Nnamdi Uba', 'Ifeanyi Uba', 'Queen Uba'],
#  'Age': [47, 52, 48, 44],
#  'Height': [1.74, 1.77, 1.74, 1.75],
#  'Nationality': ['British', 'Nigerian', 'Nigerian', 'Nigerian']}

# %%
new_dict = apply_map(ubaekwe)

# %%
new_dict
# Out:
# {'Name': 'Queen Uba',
#  'Age': [47, 52, 48, 44],
#  'Height': [1.74, 1.77, 1.74, 1.75],
#  'Nationality': 'Nigerian'}

# %%
ubaekwe
# Out:
# {'Name': 'Queen Uba',
#  'Age': [47, 52, 48, 44],
#  'Height': [1.74, 1.77, 1.74, 1.75],
#  'Nationality': 'Nigerian'}

# %%
nationality
# Out:
# 'Nigerian'

# %%
#ubaekwe["Nationality"], ubaekwe["Name"] = list(map(lambda x, y: change_nationality(x,y), ubaekwe["Nationality"], ubaekwe["Name"]))[1]

# %%
def apply_mapping(func, nationality, name):
    for x, y in func(nationality, name):
        return x, y

# %%
apply_mapping(change_nationality, ubaekwe['Nationality'], ubaekwe['Name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 apply_mapping(change_nationality, ubaekwe['Nationality'], ubaekwe['Name'])[0],[1]
#
# Cell In[53], line 2, in apply_mapping(func, nationality, name)
#       1 def apply_mapping(func, nationality, name):
# ----> 2     for x, y in func(nationality, name):
#       3         return x, y
#
# ValueError: too many values to unpack (expected 2)

# %%
list(map(lambda x, y: change_nationality(x,y), ubaekwe["Nationality"], ubaekwe["Name"]))
# Out:
# {'Name': ['Obinna Uba', 'Nnamdi Uba', 'Ifeanyi Uba', 'Queen Uba'],
#  'Age': [47, 52, 48, 44],
#  'Height': [1.74, 1.77, 1.74, 1.75],
#  'Nationality': ['British', 'British', 'British', 'British']}
